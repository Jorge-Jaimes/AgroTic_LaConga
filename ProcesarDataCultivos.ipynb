# %%
# !pip install APIMakeSens
# Out:
# ...
#      |████████████████████████████████| 51 kB 411 kB/s
# ...
#      |████████████████████████████████| 251 kB 17.4 MB/s
# ...
#   Created wheel for APIMakeSens: filename=APIMakeSens-1.0.4-py3-none-any.whl size=16530 sha256=1d9a6511664cd0bc5c4166899778df97b7b1273201e9fdbdc684170e651b7be0
#   Stored in directory: /root/.cache/pip/wheels/74/b7/f7/3050beaf8d27fd0621ce6e29ac3a88e513b565b7479b238ebf
# Successfully built APIMakeSens
# ...

# %%
# Importar la librería
from MakeSens import MakeSens
import numpy as np
# 1. Descargando los datos
# Definir los parametos 
token = 'eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJqdGkiOiJIQUNLX0xhX0NvTkdBIiwic3ZyIjoibWFrZXNlbnMuYXdzLnRoaW5nZXIuaW8iLCJ1c3IiOiJNYWtlU2VucyJ9.jzlgmaq4KdKwriVRWLfTGotWHhu5jZkHWLvOKUu0tJg' #Su token de autenticación
IdDevice = 'E2_00003' #El Id del disposito del cual va a solicita los datos
#IdDevice = 'Sutron_1' #El Id del disposito del cual va a solicita los datos
start = '2018-10-10 00:00:00' # Fecha desde la cual se quieren obtener los datos
end = '2022-04-01 00:00:00' # Fecha hasta la cual se quieren obtener los datos
frecuency = 'w' #Frecuencia de muestreo con la que quiere descargarlos datos:
                # 'w' -> Semanales, 'h' -> horarios, 'm' -> minutales

#Descargar los datos       
#for i in range(1,22):
#  name = 'E2_0000'
#  print("######")
#  print(i)
#data = MakeSens.download_data(name+str(i),start,end,frecuency,token) #Tienes los datos en un DataFrame
data = MakeSens.download_data(IdDevice,start,end,frecuency,token) #Tienes los datos en un DataFrame
#  print(data.describe())
#  print(data.shape[0])

#Descargar y guardar los datos
#format_ = 'csv' # 'csv' o 'xlsx'
#data = MakeSens.download_data(IdDevice,tmin,tmax,frecuency,token,format_)
NaN = np.nan
cultivos = {"maiz": {"temperatura": {"general": {"minima": 18, "maxima": 21, "optima": NaN}}, "precipitacion": {"general": {"minima": NaN, "maxima": NaN, "optima": 800}}, "humedad": {"general": {"minima": 70, "maxima": 84, "optima": NaN}}, "tiempo": [120, 180], "valor": "2,000"}, "arroz": {"temperatura": {"general": {"minima": 23, "maxima": 27, "optima": NaN}}, "precipitacion": {"general": {"minima": NaN, "maxima": NaN, "optima": 1200}}, "tiempo": [90, 180], "valor": "3,500"}, "tomate": {"temperatura": {"germinacion": {"minima": 11, "maxima": 34, "optima": 22.5, "tiempo": [9, 14]}, "crecimiento": {"minima": 18, "maxima": 32, "optima": 21.5, "tiempo": [27, 42]}, "produccion": {"minima": 18, "maxima": 32, "optima": 24.5}, "tiempo": [9, 14]}, "humedad": {"general": {"minima": 60, "maxima": 85, "optima": NaN}}, "luz": {"general": {"minima": 6, "maxima": 8, "optima": NaN}}, "tiempo": [45, 70], "valor": "3,500"}, "soja": {"temperatura": {"general": {"minima": 20, "maxima": 35, "optima": NaN}}, "humedad": {"general": {"minima": 70, "maxima": 90, "optima": NaN}}, "precipitacion": {"general": {"minima": 200, "maxima": 400, "optima": NaN}}, "tiempo": [60, 90], "valor": "3,500"}, "cebolla junca": {"temperatura": {"general": {"minima":
# {'temperatura': {'general': {'minima': 18, 'maxima': 21, 'optima': nan}}, 'precipitacion': {'general': {'minima': nan, 'maxima': nan, 'optima': 800}}, 'humedad': {'general': {'minima': 70, 'maxima': 84, 'optima': nan}}, 'tiempo': [120, 180], 'valor': '2,000'}
# arroz
# {'temperatura': {'general': {'minima': 23, 'maxima': 27, 'optima': nan}}, 'precipitacion': {'general': {'minima': nan, 'maxima': nan, 'optima': 1200}}, 'tiempo': [90, 180], 'valor': '3,500'}
# tomate
# {'temperatura': {'germinacion': {'minima': 11, 'maxima': 34, 'optima': 22.5, 'tiempo': [9, 14]}, 'crecimiento': {'minima': 18, 'maxima': 32, 'optima': 21.5, 'tiempo': [27, 42]}, 'produccion': {'minima': 18, 'maxima': 32, 'optima': 24.5}, 'tiempo': [9, 14]}, 'humedad': {'general': {'minima': 60, 'maxima': 85, 'optima': nan}}, 'luz': {'general': {'minima': 6, 'maxima': 8, 'optima': nan}}, 'tiempo': [45, 70], 'valor': '3,500'}
# soja
# ...

# %%
import pandas as pd
cultivosdf = pd.json_normalize(cultivos)
cultivosdf
# Out:
#    maiz.temperatura.general.minima  maiz.temperatura.general.maxima  \
# 0                               18                               21
#
#    maiz.temperatura.general.optima  maiz.precipitacion.general.minima  \
# 0                              NaN                                NaN
#
#    maiz.precipitacion.general.maxima  maiz.precipitacion.general.optima  \
# 0                                NaN                                800
#
#    maiz.humedad.general.minima  maiz.humedad.general.maxima  \
# 0                           70                           84
#
#    maiz.humedad.general.optima maiz.tiempo  ...  \
# 0                          NaN  [120, 180]  ...
#
#   pepino.temperatura.germinacion.tiempo  \
# 0                                [4, 7]
#
#    pepino.temperatura.crecimiento.minima  \
# 0                                     18
#
#    pepino.temperatura.crecimiento.maxima  \
# 0                                     27
#
#    pepino.temperatura.crecimiento.optima  \
# ...

# %%
nombres = []
indices = [-1]
for i in range(len(cultivosdf.columns)):
  
  p_index = cultivosdf.columns[i].index('.')
  nombres.append(cultivosdf.columns[i][p_index+1:])
  if i != len(cultivosdf.columns)-1:
    if cultivosdf.columns[i+1][:p_index] != cultivosdf.columns[i][:p_index]:
      indices.append(i)

indices.append(len(cultivosdf.columns))
print(len(nombres))
print(len(indices))
# Out:
# 218
# 18

# %%
columnasdf = cultivosdf.copy()
columnasdf.columns = nombres
columnasdf
# Out:
#    temperatura.general.minima  temperatura.general.maxima  \
# 0                          18                          21
#
#    temperatura.general.optima  precipitacion.general.minima  \
# 0                         NaN                           NaN
#
#    precipitacion.general.maxima  precipitacion.general.optima  \
# 0                           NaN                           800
#
#    humedad.general.minima  humedad.general.maxima humedad.general.optima  \
# 0                      70                      84                    NaN
#
#        tiempo  ... temperatura.germinacion.tiempo  \
# 0  [120, 180]  ...                         [4, 7]
#
#    temperatura.crecimiento.minima  temperatura.crecimiento.maxima  \
# 0                              18                              27
#
#    temperatura.crecimiento.optima  temperatura.crecimiento.tiempo  \
# 0                             NaN                         [7, 55]
#
# ...

# %%
columnasdf = columnasdf.iloc[:,~columnasdf.columns.duplicated()]
print(columnasdf.shape)
# Out:
# (1, 65)

# %%
lista_cultivosdf = [cultivosdf.iloc[:,indices[i-1]+1:indices[i]+1] for i in range(1,len(indices))]

# %%
import numpy as np

for i in range(len(lista_cultivosdf)):
  difcols = np.setdiff1d(columnasdf.columns,lista_cultivosdf[i].columns)
  lista_cultivosdf[i][difcols] = pd.DataFrame([[np.nan]*len(difcols)])
  columnasdf = columnasdf.append(lista_cultivosdf[i])

# %%
columnasdf.shape
# Out:
# (18, 65)

# %%
columnasdf
# Out:
#    temperatura.general.minima  temperatura.general.maxima  \
# 0                        18.0                        21.0
# 0                        18.0                        21.0
# 0                        23.0                        27.0
# 0                         NaN                         NaN
# 0                        20.0                        35.0
# 0                        12.0                        20.0
# 0                        18.0                        24.0
# 0                         NaN                         NaN
# 0                         NaN                         NaN
# 0                         NaN                         NaN
# 0                        15.0                        23.0
# 0                        13.0                        18.0
# 0                        15.0                        21.0
# 0                         NaN                         NaN
# 0                         NaN                         NaN
# ...

# %%
datacultivos = columnasdf.reset_index(level=0)
datacultivos.rename(columns = {datacultivos.columns[0]: 'nombre.cultivo'}, inplace=True)
datacultivos.dtypes
# Out:
# nombre.cultivo                     int64
# temperatura.general.minima       float64
# temperatura.general.maxima       float64
# temperatura.general.optima       float64
# precipitacion.general.minima     float64
#                                   ...
# temperatura.floracion.minima     float64
# temperatura.floracion.maxima     float64
# temperatura.floracion.optima     float64
# temperatura.floracion.tiempo      object
# temperatura.produccion.tiempo     object
# Length: 66, dtype: object

# %%
datacultivos['nombre.cultivo'] = ['todos'] + list(cultivos.keys())

# %%
print(datacultivos)
# Out:
#       nombre.cultivo  temperatura.general.minima  temperatura.general.maxima  \
# 0              todos                        18.0                        21.0
# 1               maiz                        18.0                        21.0
# 2              arroz                        23.0                        27.0
# 3             tomate                         NaN                         NaN
# 4               soja                        20.0                        35.0
# 5      cebolla junca                        12.0                        20.0
# 6   cebolla cabezona                        18.0                        24.0
# 7                ajo                         NaN                         NaN
# 8           pimenton                         NaN                         NaN
# 9              melon                         NaN                         NaN
# 10            frijol                        15.0                        23.0
# ...

# %%
dfcultivos = datacultivos.dropna(axis=1,how='all')

# %%
dfcultivos.shape
# Out:
# (18, 55)

# %%
cultivos.keys()
# Out:
# dict_keys(['maiz', 'arroz', 'tomate', 'soja', 'cebolla junca', 'cebolla cabezona', 'ajo', 'pimenton', 'melon', 'frijol', 'arveja', 'zanahoria', 'berenjena', 'calabacin', 'judia verde', 'sandia', 'pepino'])

# %%
dfcultivos.to_excel('dfcultivos.xlsx')

# %%
judiaverde = lista_cultivosdf[14].dropna(axis=1,how='all')

# %%
print(judiaverde)
# Out:
#    judia verde.temperatura.general.minima  \
# 0                                      12
#
#    judia verde.temperatura.general.maxima  \
# 0                                      25
#
#    judia verde.temperatura.general.optima judia verde.tiempo
# 0                                      18           [60, 90]

# %%
judiaverde.to_csv('judiaverde.csv')

# %%
data
# Out:
#                        humedad  irradiancia     pm10_1       pm10_2  \
# 2021-10-07 00:00:00  56.867537   116.973093  20.168083    12.345377
# 2021-10-14 00:00:00  61.402963   190.626553  19.013813  1086.101675
# 2021-10-21 00:00:00  67.397032   115.183176  26.067076  3066.371461
# 2021-10-28 00:00:00  66.582313   122.499748  21.254135  1421.977970
# 2021-11-04 00:00:00  64.776261   117.998772  24.484975   126.687127
# 2021-11-11 00:00:00  63.461586   137.015887  28.161945   792.966100
# 2021-11-18 00:00:00  65.352244   115.067691  30.768774   184.383447
# 2021-11-25 00:00:00  65.205115   120.792676  19.632794   332.934482
# 2021-12-02 00:00:00  59.292979   146.448574  18.379238  4235.441814
# 2021-12-09 00:00:00  62.484953   117.651511  28.061344  1002.460258
# 2021-12-16 00:00:00  63.134683   113.346309  25.152900  2649.622512
# 2021-12-23 00:00:00  63.144701   112.114441  28.609435   936.622902
# 2021-12-30 00:00:00  54.884718   154.133786  22.796980  1066.591609
# ...

# %%
judiaverde.valor = 7700

# %% [markdown]
# ## Análisis de datos

# %%
dfe = pd.read_excel('DfE.xlsx')
# Out:
#             Unnamed: 0      RSSID      VBat       VIn    humedad  irradiancia  \
# 0  2022-03-10 15:00:00 -75.000000  3.652916  0.997868  72.239176     0.000000
# 1  2022-03-10 19:00:00 -54.678571  3.591309  2.753946  63.355236    67.686595
# 2  2022-03-10 20:00:00 -56.517241  3.580562  1.971503  63.901818    11.861242
# 3  2022-03-10 21:00:00 -46.933333  4.045347  4.974744  65.854703     0.000000
# 4  2022-03-10 22:00:00 -46.633333  4.174901  4.979906  66.121164     0.000000
#
#    precipitacion     presion  temperatura Name_Device
# 0            0.0  896.328613    24.698958    E2_00020
# 1            0.0  893.319105    27.055848    E2_00020
# 2            0.0  892.792288    27.206475    E2_00020
# 3            0.0  892.937873    26.829750    E2_00020
# 4            0.0  893.052224    26.852542    E2_00020

# %%
data = dfe[dfe['Name_Device']=='E2_00020']

# %%
data
# Out:
#               Unnamed: 0      RSSID      VBat       VIn    humedad  \
# 0    2022-03-10 15:00:00 -75.000000  3.652916  0.997868  72.239176
# 1    2022-03-10 19:00:00 -54.678571  3.591309  2.753946  63.355236
# 2    2022-03-10 20:00:00 -56.517241  3.580562  1.971503  63.901818
# 3    2022-03-10 21:00:00 -46.933333  4.045347  4.974744  65.854703
# 4    2022-03-10 22:00:00 -46.633333  4.174901  4.979906  66.121164
# ..                   ...        ...       ...       ...        ...
# 651  2022-05-06 09:00:00 -92.216667  4.120433  4.971036  60.141477
# 652  2022-05-06 10:00:00 -92.650000  4.120433  4.969374  61.677954
# 653  2022-05-06 11:00:00 -93.200000  4.119780  4.968247  59.987364
# 654  2022-05-06 12:00:00 -92.300000  4.120581  4.967743  57.403190
# 655  2022-05-06 13:00:00 -92.216667  4.120700  4.970235  53.837182
#
#      irradiancia  precipitacion     presion  temperatura Name_Device
# 0       0.000000            0.0  896.328613    24.698958    E2_00020
# ...

# %%
def get_rangotemp(df):
  rangos = []
  for column in df.columns:
    if 'temperatura' in column and 'minima' in column:
      rangos.append(df[column][0])  
    elif 'temperatura' in column and 'maxima' in column:
      rangos.append(df[column][0])
  rango = []
  for i in range(len(rangos)-1):
    if i%2 == 0:
      rango.append([rangos[i],rangos[i+1]])
  return rango

# %%
rango = get_rangotemp(lista_cultivosdf[2])
print(rango)
# Out:
# [[11, 34], [18, 32], [18, 32]]

# %%
a = len(cultivos.keys())
tiempos = []
for i in range(len(cultivos.keys())):
  tiempos.append(get_rangotemp(lista_cultivosdf[i]))
print(tiempos)
# Out:
# [[[18, 21]], [[23, 27]], [[11, 34], [18, 32], [18, 32]], [[20, 35]], [[12, 20]], [[18, 24]], [[16, 20]], [[25, 30], [14, 25], [20, 21], [22, 23], [18, 19]], [[22, 28], [20, 23], [25, 30], [25, 30]], [[15, 23]], [[13, 18]], [[15, 21]], [[12, 35], [10, 35], [10, 35]], [[14, 15], [20, 25]], [[12, 25]], [[15, 40], [18, 26]], [[12, 30], [18, 27]]]

# %%
len(tiempos)
# Out:
# 17

# %%
[data['temperatura'].min(),data['temperatura'].max()]
# Out:
# [15.406978368890284, 18.584436548272812]

# %%
def get_optfechas(device,temprango):
  device_temprang = [device['temperatura'].min(),device['temperatura'].max()]
  if temprango[0] > device_temprang[1] or temprango[1] < device_temprang[0]:
    return []
  else:
    return np.intersect1d(device.index.values[device['temperatura']>temprango[0]],device.index.values[device['temperatura']<temprango[1]])

# %%
print(get_optfechas(data,get_rangotemp(maizdata)))
# Out:
# ['2021-10-07 00:00:00']

# %%
for i in range(len(lista_cultivosdf)):
  lista_cultivosdf[i] = lista_cultivosdf[i].dropna(axis=1,how='all')

# %%
for cultivo in lista_cultivosdf:
  print(cultivo.shape)
# Out:
# (1, 7)
# (1, 5)
# (1, 18)
# (1, 8)
# (1, 6)
# (1, 8)
# (1, 4)
# (1, 18)
# (1, 24)
# (1, 7)
# (1, 6)
# (1, 7)
# (1, 16)
# (1, 8)
# (1, 4)
# (1, 11)
# (1, 10)

# %%
print(lista_cultivosdf[7])
# Out:
#    pimenton.temperatura.germinacion.minima  \
# 0                                       25
#
#    pimenton.temperatura.germinacion.maxima  \
# 0                                       30
#
#   pimenton.temperatura.germinacion.tiempo  \
# 0                                 [9, 14]
#
#    pimenton.temperatura.crecimiento dia.minima  \
# 0                                           14
#
#    pimenton.temperatura.crecimiento dia.maxima  \
# 0                                           25
#
#   pimenton.temperatura.crecimiento dia.tiempo  \
# 0                                    [70, 80]
#
#    pimenton.temperatura.crecimiento noche.minima  \
# 0                                             20
#
#    pimenton.temperatura.crecimiento noche.maxima  \
# 0                                             21
#
#   pimenton.temperatura.crecimiento noche.tiempo  \
# 0                                      [70, 80]
#
#    pimenton.temperatura.produccion dia.minima  \
# ...

# %%
costo = pd.read_excel('tiempo.xlsx')
costo.head()
# Out:
#       Unnamed: 0 tiempo.germinacion.optimo  Kilogramo.hectarea
# 0           maiz                    [7,14]               18000
# 1          arroz                     [2,3]               11000
# 2         tomate                     [5,0]               77000
# 3           soja                     [3.5]                4500
# 4  cebolla junca                       [7]               25258

# %%
costos = [2000, 3500, 3500, 3500, 600, 3200, 6100, 1500, 2800, 3900, 6400, 3300, 1600, 600, 0, 1500, 750]

# %%
costo['Peso.hectarea'] = costos*costo['Kilogramo.hectarea']

# %%
costo2 = costo.rename(columns={costo.columns[0]:'Nombre'})

# %%
costo.iloc[4,0] = 'cebollajunca'
costo.iloc[5,0] = 'cebollacabezona'
costo.iloc[14,0] = 'judiaverde'

# %%
type(costo2['Peso.hectarea'][0])
# Out:
# numpy.int64

# %%
costo2.to_csv('costo3.csv')
